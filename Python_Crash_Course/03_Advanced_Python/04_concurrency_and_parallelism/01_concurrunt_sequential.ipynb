# %% [markdown]
#
# *What is the difference between sequential, parallel, and concurrent execution (in order)?*
#
# ---
#
# Let's explain all **three** execution styles **in sequence**, with **simple real-life and code examples**.
#
# ---
#
# ## 🔢 1. **Sequential Execution**
# - One task runs **at a time**, one **after** another.
# - **Slowest** method but **simplest**.
#
# ### 🔧 Example:
#
# ```python
# import time
#
# def task(name):
#     print(f"{name} started")
#     time.sleep(2)
#     print(f"{name} done")
#
# task("A")
# task("B")
# task("C")
# ```
#
# ### ⏱️ Output:
# ```
# A started → A done (2s)
# B started → B done (4s)
# C started → C done (6s)
# ```
#
# > Total time: **6 seconds**
#
# ### 🍳 Analogy:
# One chef cooks dish A, finishes, then dish B, then dish C — **one by one**.
#
# ---
#
# ## ⚙️ 2. **Concurrent Execution**
# - Tasks run **independently**, but **not truly at the same time**.
# - They are **started together**, but only **one runs at a time**, switching quickly.
# - Good for **I/O-bound** operations.
#
# ### 🔧 Example using `asyncio`:
#
# ```python
# import asyncio
#
# async def task(name):
#     print(f"{name} started")
#     await asyncio.sleep(2)
#     print(f"{name} done")
#
# async def main():
#     await asyncio.gather(task("A"), task("B"), task("C"))
#
# await main()
# ```
#
# ### ⏱️ Output:
# ```
# A started
# B started
# C started
# A done
# B done
# C done
# ```
#
# > Total time: **~2 seconds**
#
# ### 🍳 Analogy:
# One chef **starts 3 dishes** and switches between them while one is boiling or baking.
#
# ---
#
# ## 🧠 3. **Parallel Execution**
# - Tasks run **at the same time** using **multiple cores** (true multitasking).
# - Great for **CPU-heavy** operations (math, image processing).
#
# ### 🔧 Example using `multiprocessing`:
#
# ```python
# from multiprocessing import Process
# import time
#
# def task(name):
#     print(f"{name} started")
#     time.sleep(2)
#     print(f"{name} done")
#
# if __name__ == "__main__":
#     p1 = Process(target=task, args=("A",))
#     p2 = Process(target=task, args=("B",))
#     p3 = Process(target=task, args=("C",))
#
#     p1.start()
#     p2.start()
#     p3.start()
#
#     p1.join()
#     p2.join()
#     p3.join()
# ```
#
# ### ⏱️ Output:
# ```
# A started
# B started
# C started
# A done
# B done
# C done
# ```
#
# > Total time: **~2 seconds**
#
# ### 🍳 Analogy:
# **3 chefs** cooking dishes A, B, and C **at the same time**, each with their own kitchen.
#
# ---
#
# ## 📊 Final Comparison
#
# | Style        | Execution Flow       | Best For     | Time (3 tasks) |
# |--------------|----------------------|--------------|----------------|
# | Sequential   | A → B → C            | Simple code  | ~6 sec         |
# | Concurrent   | A↔B↔C (switching)    | I/O-bound    | ~2 sec         |
# | Parallel     | A + B + C (same time)| CPU-bound    | ~2 sec         |
#
# ---

# %%
import time
def main():
    print("Hello, World!")
    time.sleep(1)
    print("Goodbye, World!")
print("This is a simple Python script.")
s_time=time.time()
for i in range(5):
    print(f"Counting: {i}")
    starting_time = time.time()
    main()
    ending_time = time.time()
    print(f"Execution time: {ending_time - starting_time:.2f} seconds")
total_time = time.time() - s_time
print(f"Total execution time: {total_time:.2f} seconds")
# Out:
# This is a simple Python script.
# Counting: 0
# Hello, World!
# Goodbye, World!
# Execution time: 1.00 seconds
# Counting: 1
# Hello, World!
# Goodbye, World!
# Execution time: 1.00 seconds
# Counting: 2
# Hello, World!
# Goodbye, World!
# Execution time: 1.00 seconds
# Counting: 3
# Hello, World!
# Goodbye, World!
# Execution time: 1.00 seconds
# Counting: 4
# Hello, World!
# Goodbye, World!
# Execution time: 1.00 seconds
# Total execution time: 5.01 seconds

# %%
import time
import asyncio
async def main():
    print("Hello, World!")
    starting_time = time.time()
    print("Current time:", time.ctime())
    await asyncio.sleep(1)
    ending_time = time.time()
    print(f"Execution time: {ending_time - starting_time:.2f} seconds")
    print("Goodbye, World!")
    
print("This is a simple Python script.")
s_time=time.time()
await asyncio.gather(*(main() for _ in range(5)))

 
total_time = time.time() - s_time
print(f"Total execution time: {total_time:.2f} seconds")
# Out:
# This is a simple Python script.
# Hello, World!
# Current time: Sat Apr  4 05:54:11 2026
# Hello, World!
# Current time: Sat Apr  4 05:54:11 2026
# Hello, World!
# Current time: Sat Apr  4 05:54:11 2026
# Hello, World!
# Current time: Sat Apr  4 05:54:11 2026
# Hello, World!
# Current time: Sat Apr  4 05:54:11 2026
# Execution time: 1.01 seconds
# Goodbye, World!
# Execution time: 1.01 seconds
# Goodbye, World!
# Execution time: 1.01 seconds
# Goodbye, World!
# Execution time: 1.01 seconds
# Goodbye, World!
# Execution time: 1.01 seconds
# Goodbye, World!
# Total execution time: 1.01 seconds

# %%
import time
import asyncio
from concurrent.futures import ThreadPoolExecutor

def task1(name):
    print(f"{name} started and time {time.ctime()}")
    time.sleep(1)
    print(f"{name} done")
def task2(name):
    print(f"{name} started and time {time.ctime()}")
    time.sleep(2)
    print(f"{name} done")
def task3(name):
    print(f"{name} started and time {time.ctime()}")
    time.sleep(3)
    print(f"{name} done")
executor = ThreadPoolExecutor(max_workers=3)

async def run_tasks():
    loop = asyncio.get_event_loop()
    await asyncio.gather(
        loop.run_in_executor(executor, task1, "A"),
        loop.run_in_executor(executor, task2, "B"),
        loop.run_in_executor(executor, task3, "C"),
    )
start_time= time.time()
await run_tasks()
end_time= time.time()
print(f"total_time it takes:{end_time-start_time:.2f}")
# Out:
# A started and time Sat Apr  4 06:28:01 2026
# B started and time Sat Apr  4 06:28:01 2026
# C started and time Sat Apr  4 06:28:01 2026
# A done
# B done
# C done
# total_time it takes:3.02
