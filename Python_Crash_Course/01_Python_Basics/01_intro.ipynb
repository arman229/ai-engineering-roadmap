# %% [markdown]
# # What is Programming and Python?
# ## What is Programming
# Programming is a way for us to tell computers what to do. Computer is a very dumb machine and it only does what we tell it to do. Hence we learn programming and tell computers to do what we are very slow at - computation.
# If I ask you to calculate 5+6, you will immediately say 11.
# How about 23453453 X 56456?
#
# You will start searching for a calculator or jump to a new tab to calculate the same.
# We will start from 0 and by the time we end this course, I promise you will be a Job ready Python developer!
#
# ## What is Python?
#
# -   Python is a dynamically typed, general purpose programming language that supports an object-oriented programming approach as well as a functional programming approach.
# -   Python is a high-level programming language that is:
# -   Easy to read and write (uses simple English-like syntax).
# -   Portable (the same code can run on Windows, Mac, Linux without changes).
# -   Interpreted (runs line by line, no need to compile before running).
# -   It was created by Guido Van Rossum in 1991.
#
#
# ### Corrected English
#
# **"What are high-level and low-level programming languages?"**
#
# ---
#
# ## 🔹 Low-level programming languages
#
# Low-level languages are **closer to the hardware (computer)** and harder for humans to read.
#
# They give **direct control over memory and CPU**.
#
# ### Examples:
#
# * Machine language (binary: 0s and 1s)
# * Assembly language (uses mnemonics like `MOV`, `ADD`)
#
# ### Features:
#
# * Very fast execution ⚡
# * Hard to read and write
# * Not portable (depends on hardware/CPU)
# * Requires deep understanding of computer architecture ### Corrected English
#
# **"What are high-level and low-level programming languages?"**
#
# ---
#
# ## 🔹 Low-level programming languages
#
# Low-level languages are **closer to the hardware (computer)** and harder for humans to read.
#
# They give **direct control over memory and CPU**.
#
# ### Examples:
#
# * Machine language (binary: 0s and 1s)
# * Assembly language (uses mnemonics like `MOV`, `ADD`)
#
# ### Features:
#
# * Very fast execution ⚡
# * Hard to read and write
# * Not portable (depends on hardware/CPU)
# * Requires deep understanding of computer architecture
#
#
# ## 🔹 High-level programming languages
#
# High-level languages are **closer to human language** and easier to understand.
#
# They hide hardware details and let you focus on logic.
#
# ### Examples:
#
# * Python
# * Java
# * C++
# * JavaScript
#
# ### Features:
#
# * Easy to learn and write 👍
# * More readable and maintainable
# * Portable (works on different systems)
# * Slower than low-level languages (slightly, due to abstraction)
#
#
#
# ## What happens when you install Python?
# - The Python installer (from python.org or Anaconda, etc.) includes:
#     - Python Interpreter → The program that reads and executes your .py files.
#     - Standard Library → A collection of built-in modules and tools.
#     - PIP (Package Installer for Python) → To install extra libraries.
#
# ## Python is **Dynamically Typed**
#
# * **Typing** means how the language handles **data types** (integer, string, float, etc.).
# * In **statically typed languages** (like C, Java):
#
#   * You must **declare the type** of a variable before using it.
#
#   ```java
#   int x = 10;  // x is an integer
#   x = "hello"; // ❌ Error
#   ```
# * In **dynamically typed languages** (like Python):
#
#   * You **don’t need to declare the type**. Python figures it out automatically at runtime.
#
#   ```python
#   x = 10        # x is now an integer
#   x = "hello"   # now x is a string (allowed in Python)
#   ```
# ✅ This makes Python flexible and easy for beginners, but can cause runtime errors if types are mixed incorrectly.
#
#
# General-purpose (you can use it for many things: web apps, AI, data science, automation, games, etc.).
# ## Features of Python
#
# -   Python is simple and easy to understand.
# -   It is Interpreted and platform-independent which makes debugging very easy.
# -   Python is an open-source programming language.
# -   Python provides very big library support. Some of the popular libraries include NumPy, Tensorflow, Selenium, OpenCV, etc.
# -   It is possible to integrate other programming languages within python.
#
# ## What is Python used for
#
# -   Python is used in Data Visualization to create plots and graphical representations.
# -   Python helps in Data Analytics to analyze and understand raw data for insights and trends.
# -   It is used in AI and Machine Learning to simulate human behavior and to learn from past data without hard coding.
# -   It is used to create web applications.
# -   It can be used to handle databases.
# -   It is used in business and accounting to perform complex mathematical operations along with quantitative and qualitative analysis.
#
# ## What is mypy?
# - mypy is a static type checker for Python.
# - Python itself is dynamically typed, but with mypy (and type hints) you can add optional type checking.
# - It doesn’t change how Python runs — it just checks your code before execution for potential type errors.
