# %% [markdown]
# # Match-Case
# match-case is Python’s pattern matching statement that lets you execute code based on which value or pattern a variable matches, with optional conditions and a default case.

# %%
value = 4
match value:
    case 1:
        print("One")
    case 2:
        print("Two")
    case 3:
        print("Three")
    case _ if value > 3:
        print("Greater than Three")
# Out:
# Greater than Three

# %%
x = int(input("Enter the value of x: "))
# x is the variable to match
match x: 
    case 0:
        print("x is zero") 
    case 4:
        print("case is 4")
    case _ if x!=90:
        print(x, "is not 90")
    case _ if x!=80:
        print(x, "is not 80")
    case _:
        print(x)
# Out:
# 3 is not 90

# %%
status_code = 200

match status_code:
    case 200:
        print("OK")
    case 404:
        print("Not Found")
    case 500:
        print("Internal Server Error")
    case _:
        print("Unknown status")
# Out:
# OK
